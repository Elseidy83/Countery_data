# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns

sns.set(rc={'figure.figsize': [7, 7]}, font_scale=1.2)

# %%
df = pd.read_csv('Country-data.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
ds = df.drop(['country'],axis=1)

# %%
sns.heatmap(ds.corr(), annot=True, fmt='.1f')
# Out:
# <AxesSubplot:>

# %%
def get_sum(rw):
    return rw['child_mort']+ rw['exports']+rw['health']+rw['imports']+rw['income']+rw['inflation']+rw['life_expec']+rw['total_fer']+rw['gdpp']

# %%
dd = ds.corr().abs()

# %%
dd.apply(get_sum).sort_values(ascending=False)
# Out:
# life_expec    4.680703
# child_mort    4.676484
# total_fer     4.558757
# gdpp          4.535423
# income        4.450213
# exports       3.849008
# inflation     2.823954
# imports       2.658646
# health        2.548813
# dtype: float64

# %%
ds = ds.drop(['inflation','imports','health'],axis=1)

# %%
ds
# Out:
#      child_mort  exports  income  life_expec  total_fer   gdpp
# 0          90.2     10.0    1610        56.2       5.82    553
# 1          16.6     28.0    9930        76.3       1.65   4090
# 2          27.3     38.4   12900        76.5       2.89   4460
# 3         119.0     62.3    5900        60.1       6.16   3530
# 4          10.3     45.5   19100        76.8       2.13  12200
# ..          ...      ...     ...         ...        ...    ...
# 162        29.2     46.6    2950        63.0       3.50   2970
# 163        17.1     28.5   16500        75.4       2.47  13500
# 164        23.3     72.0    4490        73.1       1.95   1310
# 165        56.3     30.0    4480        67.5       4.67   1310
# 166        83.1     37.0    3280        52.0       5.40   1460
#
# [167 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(ds)

# %%
x_scaled
# Out:
# array([[ 1.29153238, -1.13827979, -0.8082454 , -1.61909203,  1.90288227,
#         -0.67917961],
#        [-0.5389489 , -0.47965843, -0.3753689 ,  0.64786643, -0.85997281,
#         -0.48562324],
#        [-0.27283273, -0.09912164, -0.22084447,  0.67042323, -0.0384044 ,
#         -0.46537561],
#        ...,
#        [-0.37231541,  1.13030491, -0.65840354,  0.28695762, -0.66120626,
#         -0.63775406],
#        [ 0.44841668, -0.40647827, -0.65892382, -0.34463279,  1.14094382,
#         -0.63775406],
#        [ 1.11495062, -0.15034774, -0.72135793, -2.09278484,  1.6246091 ,
#         -0.62954556]])

# %%
sns.pairplot(ds)

# %%
plt.scatter(x_scaled[:, 0], x_scaled[:, 1])

# %%
import scipy.cluster.hierarchy as sch

# %%
dendrogram = sch.dendrogram(sch.linkage(ds, method='ward'))

# %%
model = AgglomerativeClustering(n_clusters=5)
clusters = model.fit_predict(x_scaled)
clusters
# Out:
# array([3, 2, 2, 1, 2, 2, 2, 0, 0, 2, 0, 2, 1, 2, 2, 0, 2, 3, 1, 1, 2, 1,
#        2, 0, 2, 3, 3, 1, 3, 0, 1, 3, 3, 2, 2, 2, 1, 3, 1, 2, 3, 2, 2, 2,
#        0, 2, 2, 1, 2, 1, 1, 2, 1, 0, 0, 1, 1, 2, 0, 1, 0, 2, 1, 3, 3, 1,
#        3, 2, 0, 1, 1, 2, 1, 0, 0, 0, 2, 0, 2, 2, 1, 1, 0, 1, 1, 2, 2, 1,
#        1, 2, 2, 4, 2, 1, 3, 2, 2, 3, 4, 1, 2, 1, 2, 1, 2, 1, 3, 1, 1, 1,
#        0, 0, 3, 3, 0, 2, 1, 2, 2, 2, 1, 2, 0, 0, 2, 2, 1, 1, 2, 1, 2, 2,
#        3, 4, 2, 2, 1, 1, 2, 0, 2, 2, 1, 2, 0, 0, 1, 1, 2, 1, 3, 1, 2, 2,
#        1, 3, 2, 0, 0, 0, 2, 1, 1, 2, 2, 1, 3], dtype=int64)

# %%
plt.scatter(x_scaled[:, 0], x_scaled[:,7], c=clusters, cmap='viridis')

# %%
df['Clusters'] = clusters
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  Clusters
# 0         9.44        56.2       5.82    553         3
# 1         4.49        76.3       1.65   4090         2
# 2        16.10        76.5       2.89   4460         2
# 3        22.40        60.1       6.16   3530         1
# 4         1.44        76.8       2.13  12200         2
# ..         ...         ...        ...    ...       ...
# 162       2.62        63.0       3.50   2970         1
# 163      45.90        75.4       2.47  13500         2
# 164      12.10        73.1       1.95   1310         2
# 165      23.60        67.5       4.67   1310         1
# 166      14.00        52.0       5.40   1460         3
#
# [167 rows x 11 columns]

# %%
df.groupby('Clusters').describe().transpose()
# Out:
# Clusters                     0             1             2            3  \
# child_mort count     28.000000     51.000000     64.000000    21.000000
#            mean       5.410714     55.729412     14.270313   117.700000
#            std        2.735005     24.199093      7.363977    30.370924
#            min        2.600000     17.400000      3.200000    81.000000
#            25%        3.900000     35.850000      8.425000    93.600000
# ...                        ...           ...           ...          ...
# gdpp       min    22500.000000    327.000000   1310.000000   231.000000
#            25%    35225.000000    977.500000   4647.500000   446.000000
#            50%    43150.000000   1490.000000   8040.000000   575.000000
#            75%    49100.000000   3210.000000  12125.000000   758.000000
#            max    87800.000000  17100.000000  30800.000000  2330.000000
#
# Clusters                      4
# child_mort count       3.000000
#            mean        4.133333
#            std         2.309401
#            min         2.800000
#            25%         2.800000
# ...                         ...
# gdpp       min     21100.000000
#            25%     33850.000000
#            50%     46600.000000
#            75%     75800.000000
#            max    105000.000000
#
# [72 rows x 5 columns]
